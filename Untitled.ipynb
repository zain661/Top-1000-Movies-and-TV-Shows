# %%
import pandas as pd

# %%
df = pd.read_csv('imdb_top_1000.csv')

# %%
df.drop(["Poster_Link","Runtime","Released_Year","Certificate","Overview","IMDB_Rating","Meta_score","Star1","Star2","Star3","Star4","No_of_Votes","Gross"],axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# Series_Title    0
# Genre           0
# Director        0
# dtype: int64

# %%
df['Genre'].value_counts()
# Out:
# Drama                        85
# Drama, Romance               37
# Comedy, Drama                35
# Comedy, Drama, Romance       31
# Action, Crime, Drama         30
#                              ..
# Adventure, Thriller           1
# Animation, Action, Sci-Fi     1
# Action, Crime, Comedy         1
# Animation, Crime, Mystery     1
# Adventure, Comedy, War        1
# Name: Genre, Length: 202, dtype: int64

# %%
df['Genre'].value_counts().head(1)
# Out:
# Drama    85
# Name: Genre, dtype: int64

# %%
df_2 = df['Genre'].value_counts()

# %%
df_2
# Out:
# Drama                        85
# Drama, Romance               37
# Comedy, Drama                35
# Comedy, Drama, Romance       31
# Action, Crime, Drama         30
#                              ..
# Adventure, Thriller           1
# Animation, Action, Sci-Fi     1
# Action, Crime, Comedy         1
# Animation, Crime, Mystery     1
# Adventure, Comedy, War        1
# Name: Genre, Length: 202, dtype: int64

# %%
df_2 = df['Genre'].value_counts().reset_index()

# %%
df_2
# Out:
#                          index  Genre
# 0                        Drama     85
# 1               Drama, Romance     37
# 2                Comedy, Drama     35
# 3       Comedy, Drama, Romance     31
# 4         Action, Crime, Drama     30
# ..                         ...    ...
# 197        Adventure, Thriller      1
# 198  Animation, Action, Sci-Fi      1
# 199      Action, Crime, Comedy      1
# 200  Animation, Crime, Mystery      1
# 201     Adventure, Comedy, War      1
#
# [202 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(50,50))
sns.barplot(x='index',y='Genre',data=df_2)
plt.xticks(rotation=90)
plt.show()

# %%
df_3 = df['Director'].value_counts().reset_index()

# %%
df_3
# Out:
#                 index  Director
# 0    Alfred Hitchcock        14
# 1    Steven Spielberg        13
# 2      Hayao Miyazaki        11
# 3     Martin Scorsese        10
# 4      Akira Kurosawa        10
# ..                ...       ...
# 543    Neill Blomkamp         1
# 544   Tomas Alfredson         1
# 545      Duncan Jones         1
# 546   Jacques Audiard         1
# 547    George Stevens         1
#
# [548 rows x 2 columns]

# %%
plt.figure(figsize=(50,50))
sns.barplot(x='index',y='Director',data=df_3)
plt.xticks(rotation=90)
plt.show()
